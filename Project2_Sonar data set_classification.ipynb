# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('sonar.csv',header=None)

# %%
df.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# 3  0.0040  0.0117   R
# 4  0.0107  0.0094   R
#
# [5 rows x 61 columns]

# %%
df.shape
# Out:
# (208, 61)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       208 non-null    float64
#  1   1       208 non-null    float64
#  2   2       208 non-null    float64
#  3   3       208 non-null    float64
#  4   4       208 non-null    float64
#  5   5       208 non-null    float64
#  6   6       208 non-null    float64
#  7   7       208 non-null    float64
#  8   8       208 non-null    float64
#  9   9       208 non-null    float64
#  10  10      208 non-null    float64
#  11  11      208 non-null    float64
#  12  12      208 non-null    float64
#  13  13      208 non-null    float64
#  14  14      208 non-null    float64
#  15  15      208 non-null    float64
#  16  16      208 non-null    float64
#  17  17      208 non-null    float64
#  18  18      208 non-null    float64
#  19  19      208 non-null    float64
#  20  20      208 non-null    float64
#  21  21      208 non-null    float64
#  22  22      208 non-null    float64
#  23  23      208 non-null    float64
#  24  24      208 non-null    float64
#  25  25      208 non-null    float64
#  26  26      208 non-null    float64
#  27  27      208 non-null    float64
#  28  28      208 non-null    float64
#  29  29      208 non-null    float64
#  30  30      208 non-null    float64
#  31  31      208 non-null    float64
#  32  32      208 non-null    float64
#  33  33      208 non-null    float64
#  34  34      208 non-null    float64
#  35  35      208 non-null    float64
#  36  36      208 non-null    float64
#  37  37      208 non-null    float64
#  38  38      208 non-null    float64
#  39  39      208 non-null    float64
#  40  40      208 non-null    float64
#  41  41      208 non-null    float64
#  42  42      208 non-null    float64
#  43  43      208 non-null    float64
#  44  44      208 non-null    float64
#  45  45      208 non-null    float64
#  46  46      208 non-null    float64
#  47  47      208 non-null    float64
#  48  48      208 non-null    float64
#  49  49      208 non-null    float64
#  50  50      208 non-null    float64
#  51  51      208 non-null    float64
#  52  52      208 non-null    float64
#  53  53      208 non-null    float64
#  54  54      208 non-null    float64
#  55  55      208 non-null    float64
#  56  56      208 non-null    float64
#  57  57      208 non-null    float64
#  58  58      208 non-null    float64
#  59  59      208 non-null    float64
#  60  60      208 non-null    object
# dtypes: float64(60), object(1)
# memory usage: 99.2+ KB

# %%
df.isnull().sum()  # to check NaN
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
#      ..
# 56    0
# 57    0
# 58    0
# 59    0
# 60    0
# Length: 61, dtype: int64

# %%
df.describe()
# Out:
#                0           1           2           3           4           5   \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.029164    0.038437    0.043832    0.053892    0.075202    0.104570
# std      0.022991    0.032960    0.038428    0.046528    0.055552    0.059105
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013350    0.016450    0.018950    0.024375    0.038050    0.067025
# 50%      0.022800    0.030800    0.034300    0.044050    0.062500    0.092150
# 75%      0.035550    0.047950    0.057950    0.064500    0.100275    0.134125
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#                6           7           8           9   ...          50  \
# count  208.000000  208.000000  208.000000  208.000000  ...  208.000000
# mean     0.121747    0.134799    0.178003    0.208259  ...    0.016069
# std      0.061788    0.085152    0.118387    0.134416  ...    0.012008
# min      0.003300    0.005500    0.007500    0.011300  ...    0.000000
# 25%      0.080900    0.080425    0.097025    0.111275  ...    0.008425
# 50%      0.106950    0.112100    0.152250    0.182400  ...    0.013900
# 75%      0.154000    0.169600    0.233425    0.268700  ...    0.020825
# max      0.372900    0.459000    0.682800    0.710600  ...    0.100400
#
#                51          52          53          54          55          56  \
# count  208.000000  208.000000  208.000000  208.000000  208.000000  208.000000
# mean     0.013420    0.010709    0.010941    0.009290    0.008222    0.007820
# std      0.009634    0.007060    0.007301    0.007088    0.005736    0.005785
# min      0.000800    0.000500    0.001000    0.000600    0.000400    0.000300
# 25%      0.007275    0.005075    0.005375    0.004150    0.004400    0.003700
# 50%      0.011400    0.009550    0.009300    0.007500    0.006850    0.005950
# 75%      0.016725    0.014900    0.014500    0.012100    0.010575    0.010425
# max      0.070900    0.039000    0.035200    0.044700    0.039400    0.035500
#
#                57          58          59
# count  208.000000  208.000000  208.000000
# mean     0.007949    0.007941    0.006507
# std      0.006470    0.006181    0.005031
# min      0.000300    0.000100    0.000600
# 25%      0.003600    0.003675    0.003100
# 50%      0.005800    0.006400    0.005300
# 75%      0.010350    0.010325    0.008525
# max      0.044000    0.036400    0.043900
#
# [8 rows x 60 columns]

# %%
#class distribution
df.groupby(60).size()
# Out:
# 60
# M    111
# R     97
# dtype: int64

# %%
#histograms
df.hist(sharex=False, sharey=False,xlabelsize=1,ylabelsize=1,figsize=(12,12))
plt.show()

# %%
#density 
df.plot(kind='density',subplots=True,layout=(8,8),sharex=False,legend=False,fontsize=1,figsize=(12,12))
plt.show()

# %%
top_corr_features=df.corr().index
plt.figure(figsize=(30,30))
sns.heatmap(df[top_corr_features].corr(),annot=True,cmap='RdYlGn')

# %%
#algorithm evaluations
x=df.iloc[:,0:-1]
x.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      50      51      52      53      54      55      56  \
# 0  0.2111  ...  0.0232  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180
# 1  0.2872  ...  0.0125  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140
# 2  0.6194  ...  0.0033  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316
# 3  0.1264  ...  0.0241  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050
# 4  0.4459  ...  0.0156  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072
#
#        57      58      59
# 0  0.0084  0.0090  0.0032
# 1  0.0049  0.0052  0.0044
# 2  0.0164  0.0095  0.0078
# 3  0.0044  0.0040  0.0117
# 4  0.0048  0.0107  0.0094
#
# [5 rows x 60 columns]

# %%
y=df.iloc[:,-1]
y.head()
# Out:
# 0    R
# 1    R
# 2    R
# 3    R
# 4    R
# Name: 60, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#checking some algorithms
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
mnb=MultinomialNB()
mnb.fit(x_train,y_train)
predmnb=mnb.predict(x_test)
print('accuracy score',accuracy_score(y_test,predmnb))
print('confusion matrix',confusion_matrix(y_test,predmnb))
print('classification report',classification_report(y_test,predmnb))
# Out:
# accuracy score 0.8333333333333334
# confusion matrix [[22  4]
#  [ 3 13]]
# classification report               precision    recall  f1-score   support
#
#            M       0.88      0.85      0.86        26
#            R       0.76      0.81      0.79        16
#
#     accuracy                           0.83        42
#    macro avg       0.82      0.83      0.83        42
# weighted avg       0.84      0.83      0.83        42

# %%
def svckernel(ker):
    svc=SVC(kernel=ker)
    svc.fit(x_train,y_train)
    svc.score(x_train,y_train)
    predsvc=svc.predict(x_test)
    print(accuracy_score(y_test,predsvc))
    print(confusion_matrix(y_test,predsvc))
    print(classification_report(y_test,predsvc))

# %%
svckernel('rbf')
# Out:
# 0.8333333333333334
# [[21  5]
#  [ 2 14]]
#               precision    recall  f1-score   support
#
#            M       0.91      0.81      0.86        26
#            R       0.74      0.88      0.80        16
#
#     accuracy                           0.83        42
#    macro avg       0.82      0.84      0.83        42
# weighted avg       0.85      0.83      0.84        42

# %%
svckernel('poly')
# Out:
# 0.7857142857142857
# [[19  7]
#  [ 2 14]]
#               precision    recall  f1-score   support
#
#            M       0.90      0.73      0.81        26
#            R       0.67      0.88      0.76        16
#
#     accuracy                           0.79        42
#    macro avg       0.79      0.80      0.78        42
# weighted avg       0.81      0.79      0.79        42

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
preddtc=dtc.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 0.6428571428571429
# [[16 10]
#  [ 5 11]]
#               precision    recall  f1-score   support
#
#            M       0.76      0.62      0.68        26
#            R       0.52      0.69      0.59        16
#
#     accuracy                           0.64        42
#    macro avg       0.64      0.65      0.64        42
# weighted avg       0.67      0.64      0.65        42

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
predknn=knn.predict(x_test)
print(accuracy_score(y_test,predknn))
print(confusion_matrix(y_test,predknn))
print(classification_report(y_test,predknn))
# Out:
# 0.8571428571428571
# [[21  5]
#  [ 1 15]]
#               precision    recall  f1-score   support
#
#            M       0.95      0.81      0.88        26
#            R       0.75      0.94      0.83        16
#
#     accuracy                           0.86        42
#    macro avg       0.85      0.87      0.85        42
# weighted avg       0.88      0.86      0.86        42

# %%
for k in range(25):
    k_value=k+1
    knn=KNeighborsClassifier(n_neighbors=k_value)
    knn.fit(x_train,y_train)
    y_pred=knn.predict(x_test)
    print('accuracy score is',accuracy_score(y_test,y_pred),'at k-value',k_value)
# Out:
# accuracy score is 0.8809523809523809 at k-value 1
# accuracy score is 0.8809523809523809 at k-value 2
# accuracy score is 0.8809523809523809 at k-value 3
# accuracy score is 0.9047619047619048 at k-value 4
# accuracy score is 0.8571428571428571 at k-value 5
# accuracy score is 0.8095238095238095 at k-value 6
# accuracy score is 0.8095238095238095 at k-value 7
# accuracy score is 0.7857142857142857 at k-value 8
# accuracy score is 0.8333333333333334 at k-value 9
# accuracy score is 0.7857142857142857 at k-value 10
# accuracy score is 0.7619047619047619 at k-value 11
# accuracy score is 0.7857142857142857 at k-value 12
# accuracy score is 0.7619047619047619 at k-value 13
# accuracy score is 0.7619047619047619 at k-value 14
# accuracy score is 0.7619047619047619 at k-value 15
# accuracy score is 0.7619047619047619 at k-value 16
# accuracy score is 0.7380952380952381 at k-value 17
# accuracy score is 0.7380952380952381 at k-value 18
# accuracy score is 0.7142857142857143 at k-value 19
# accuracy score is 0.7619047619047619 at k-value 20
# accuracy score is 0.7380952380952381 at k-value 21
# accuracy score is 0.7619047619047619 at k-value 22
# accuracy score is 0.7142857142857143 at k-value 23
# accuracy score is 0.7142857142857143 at k-value 24
# accuracy score is 0.7142857142857143 at k-value 25

# %%
knn_=KNeighborsClassifier(n_neighbors=4)
knn_.fit(x_train,y_train)
knn_.score(x_train,y_train)
predknn_=knn_.predict(x_test)
print(accuracy_score(y_test,predknn_))
print(confusion_matrix(y_test,predknn_))
print(classification_report(y_test,predknn_))
# Out:
# 0.9047619047619048
# [[24  2]
#  [ 2 14]]
#               precision    recall  f1-score   support
#
#            M       0.92      0.92      0.92        26
#            R       0.88      0.88      0.88        16
#
#     accuracy                           0.90        42
#    macro avg       0.90      0.90      0.90        42
# weighted avg       0.90      0.90      0.90        42

# %%
from sklearn.tree import DecisionTreeClassifier
def decisiontree(cr):
    dtc=DecisionTreeClassifier(criterion=cr)
    dtc.fit(x_train,y_train)
    preddtc=dtc.predict(x_test)
    print(accuracy_score(y_test,preddtc))
    print(confusion_matrix(y_test,preddtc))
    print(classification_report(y_test,preddtc))

# %%
decisiontree('gini')
# Out:
# 0.6190476190476191
# [[15 11]
#  [ 5 11]]
#               precision    recall  f1-score   support
#
#            M       0.75      0.58      0.65        26
#            R       0.50      0.69      0.58        16
#
#     accuracy                           0.62        42
#    macro avg       0.62      0.63      0.62        42
# weighted avg       0.65      0.62      0.62        42

# %%
decisiontree('entropy')
# Out:
# 0.7619047619047619
# [[17  9]
#  [ 1 15]]
#               precision    recall  f1-score   support
#
#            M       0.94      0.65      0.77        26
#            R       0.62      0.94      0.75        16
#
#     accuracy                           0.76        42
#    macro avg       0.78      0.80      0.76        42
# weighted avg       0.82      0.76      0.76        42

# %%
svc=SVC(kernel='rbf')
svc.fit(x_train,y_train)
svc.score(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.8333333333333334
# [[21  5]
#  [ 2 14]]
#               precision    recall  f1-score   support
#
#            M       0.91      0.81      0.86        26
#            R       0.74      0.88      0.80        16
#
#     accuracy                           0.83        42
#    macro avg       0.82      0.84      0.83        42
# weighted avg       0.85      0.83      0.84        42

# %%
# here we have to take cross_validation without applying train test
from sklearn.model_selection import cross_val_score
svcscores=cross_val_score(svc,x,y,cv=5)
print(svcscores)
print(svcscores.mean(),svcscores.std())
# Out:
# [0.5        0.73809524 0.45238095 0.73170732 0.3902439 ]
# 0.5624854819976771 0.14503063161582408

# %%
from sklearn.ensemble import RandomForestClassifier   # bagging or parallel ensemble technique
rf=RandomForestClassifier(n_estimators=100,random_state=42)
#RandomForestClassifier(100)....default
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
print(accuracy_score(y_test,predrf))
print(confusion_matrix(y_test,predrf))
print(classification_report(y_test,predrf))
# Out:
# 0.8571428571428571
# [[22  4]
#  [ 2 14]]
#               precision    recall  f1-score   support
#
#            M       0.92      0.85      0.88        26
#            R       0.78      0.88      0.82        16
#
#     accuracy                           0.86        42
#    macro avg       0.85      0.86      0.85        42
# weighted avg       0.86      0.86      0.86        42

# %%
from sklearn.ensemble import AdaBoostClassifier   # for sequential or boosting ensemble technique
#AdaBoostClassifier(base_estimator=desion tree classifier(),n_estimator=50,learning_rate=1.0)
ad=AdaBoostClassifier()

ad.fit(x_train,y_train)
predad=ad.predict(x_test)
print(accuracy_score(y_test,predad))
print(confusion_matrix(y_test,predad))
print(classification_report(y_test,predad))
# Out:
# 0.7619047619047619
# [[19  7]
#  [ 3 13]]
#               precision    recall  f1-score   support
#
#            M       0.86      0.73      0.79        26
#            R       0.65      0.81      0.72        16
#
#     accuracy                           0.76        42
#    macro avg       0.76      0.77      0.76        42
# weighted avg       0.78      0.76      0.77        42

# %%
#hyperparameter tunning: gridsearchcv
from sklearn.model_selection import GridSearchCV
parameters={'kernel':('linear','rbf'),'C':[1,10]}
clf=GridSearchCV(svc,parameters)
clf.fit(x_train,y_train)

sorted(clf.cv_results_.keys())
# Out:
# ['mean_fit_time',
#  'mean_score_time',
#  'mean_test_score',
#  'param_C',
#  'param_kernel',
#  'params',
#  'rank_test_score',
#  'split0_test_score',
#  'split1_test_score',
#  'split2_test_score',
#  'split3_test_score',
#  'split4_test_score',
#  'std_fit_time',
#  'std_score_time',
#  'std_test_score']

# %%
print(clf.best_params_) #earlier calculated rbf as best parameter for svm
# Out:
# {'C': 10, 'kernel': 'rbf'}

# %%
sv=SVC(kernel='rbf',C=10)
sv.fit(x_train,y_train)
pred=sv.predict(x_test)
print(accuracy_score(y_test,pred))
# Out:
# 0.9047619047619048

# %%
#lets save a model
from sklearn.externals import joblib
#save the model as a pickle in a file
joblib.dump(sv,'sonar.pkl')
# Out:
# ['sonar.pkl']
